# %%
base = "/Volumes/workspace/raw/synthea_csv" 

display(dbutils.fs.ls(base))

patients = spark.read.option("header", True).csv(base + "/patients.csv")
encounters = spark.read.option("header", True).csv(base + "/encounters.csv")

print("patients rows: ", patients.count())
print("encounters rows: ", encounters.count())
display(encounters.limit(5))
display(patients.limit(5))

# %%
encounters.select("ENCOUNTERCLASS").distinct().show()
