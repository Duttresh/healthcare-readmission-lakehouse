-- %%
SELECT 1

-- %%
-- Use the existing catalog
USE CATALOG workspace;

-- Medallion schemas
CREATE SCHEMA IF NOT EXISTS raw    COMMENT 'Landing zone for raw source files';
CREATE SCHEMA IF NOT EXISTS bronze COMMENT 'Raw data as Delta tables';
CREATE SCHEMA IF NOT EXISTS silver COMMENT 'Cleaned and conformed data';
CREATE SCHEMA IF NOT EXISTS gold   COMMENT 'Features, predictions, reporting';

-- Volume to hold the uploaded CSV files
CREATE VOLUME IF NOT EXISTS raw.synthea_csv
COMMENT 'Synthea synthetic patient CSV files';

-- %%
SHOW SCHEMAS IN workspace

-- %%
show volumes in workspace.raw
